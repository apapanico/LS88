# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup-and-Load-Data" data-toc-modified-id="Setup-and-Load-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup and Load Data</a></span></li><li><span><a href="#Defender-Distance" data-toc-modified-id="Defender-Distance-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Defender Distance</a></span></li><li><span><a href="#Shot-Distance" data-toc-modified-id="Shot-Distance-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Shot Distance</a></span></li><li><span><a href="#Shot-Distance-and-Defender-Distance" data-toc-modified-id="Shot-Distance-and-Defender-Distance-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Shot Distance and Defender Distance</a></span><ul class="toc-item"><li><span><a href="#Hexbin-Plot" data-toc-modified-id="Hexbin-Plot-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Hexbin Plot</a></span></li></ul></li><li><span><a href="#Expected-Shot-Value" data-toc-modified-id="Expected-Shot-Value-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Expected Shot Value</a></span></li><li><span><a href="#An-Improved-Shooting-Metric" data-toc-modified-id="An-Improved-Shooting-Metric-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>An Improved Shooting Metric</a></span><ul class="toc-item"><li><span><a href="#Player-Points-Above-Average-per-FGA" data-toc-modified-id="Player-Points-Above-Average-per-FGA-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Player Points Above Average per FGA</a></span></li><li><span><a href="#Team-Points-Above-Average-per-85-FGA" data-toc-modified-id="Team-Points-Above-Average-per-85-FGA-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Team Points Above Average per 85 FGA</a></span></li><li><span><a href="#Player-ESV" data-toc-modified-id="Player-ESV-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Player ESV</a></span></li></ul></li><li><span><a href="#Does-Defender-Distance-Relate-to-Shooter-Quality?" data-toc-modified-id="Does-Defender-Distance-Relate-to-Shooter-Quality?-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Does Defender Distance Relate to Shooter Quality?</a></span></li></ul></div>

# %% [markdown]
# # Expected Value Modeling for NBA Shot Locations
#
# We should expect that two important drivers of the likelihood of making a shot are the shot distance and how near the closest defender is.  Using data obtained from NBA.com for the 2014-2015 season, this demo explores how you can build an expected value model for shooting.

# %% [markdown]
# ## Setup and Load Data

# %%
# %matplotlib inline
import datascience as ds
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
t = ds.Table.read_table('shot_logs_2014_15.csv.gz', sep=',')

# %%
t.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>GAME_ID</th> <th>MATCHUP</th> <th>LOCATION</th> <th>W</th> <th>FINAL_MARGIN</th> <th>SHOT_NUMBER</th> <th>PERIOD</th> <th>GAME_CLOCK</th> <th>SHOT_CLOCK</th> <th>DRIBBLES</th> <th>TOUCH_TIME</th> <th>SHOT_DIST</th> <th>PTS_TYPE</th> <th>SHOT_RESULT</th> <th>CLOSEST_DEFENDER</th> <th>CLOSEST_DEFENDER_PLAYER_ID</th> <th>CLOSE_DEF_DIST</th> <th>FGM</th> <th>PTS</th> <th>playerName</th> <th>SHOT_RESULT_BIN</th> <th>PTS_MADE</th> <th>CLOSE_DEF_DIST_ROUNDED</th> <th>SHOT_DIST_ROUNDED</th> <th>SHOT_DIST_BUCKET</th> <th>DATE</th> <th>PLAYER_TEAM</th> <th>OPP_TEAM</th> <th>HOME_TEAM</th> <th>AWAY_TEAM</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>21401229</td> <td>GSW vs. DEN</td> <td>H       </td> <td>W   </td> <td>7           </td> <td>1          </td> <td>2     </td> <td>02:05     </td> <td>10.6      </td> <td>2       </td> <td>3.3       </td> <td>6.5      </td> <td>2       </td> <td>made       </td> <td>Nurkic, Jusuf   </td> <td>203994                    </td> <td>2.1           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>2                     </td> <td>6.5              </td> <td>3-10            </td> <td>2015-04-15</td> <td>GSW        </td> <td>DEN     </td> <td>GSW      </td> <td>DEN      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>1          </td> <td>1     </td> <td>03:55     </td> <td>6.2       </td> <td>1       </td> <td>1.8       </td> <td>4        </td> <td>2       </td> <td>missed     </td> <td>Koufos, Kosta   </td> <td>201585                    </td> <td>1.9           </td> <td>0   </td> <td>0   </td> <td>Andrew Bogut</td> <td>0              </td> <td>0       </td> <td>2                     </td> <td>4                </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>2          </td> <td>1     </td> <td>03:54     </td> <td>5.2       </td> <td>0       </td> <td>0         </td> <td>2.8      </td> <td>2       </td> <td>made       </td> <td>Koufos, Kosta   </td> <td>201585                    </td> <td>2.2           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>2                     </td> <td>3                </td> <td>0-3             </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>3          </td> <td>3     </td> <td>10:02     </td> <td>16        </td> <td>0       </td> <td>1.5       </td> <td>8.4      </td> <td>2       </td> <td>made       </td> <td>Udrih, Beno     </td> <td>2757                      </td> <td>4.4           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>4                     </td> <td>8.5              </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>4          </td> <td>3     </td> <td>08:26     </td> <td>1.4       </td> <td>0       </td> <td>0         </td> <td>4.5      </td> <td>2       </td> <td>made       </td> <td>Randolph, Zach  </td> <td>2216                      </td> <td>4.4           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>4                     </td> <td>4.5              </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (203585 rows omitted)</p

# %% [markdown]
# ## Defender Distance
# There are lots of things you could do with this data but let's just jump right in with defender distance.
#
# We use the 1ft buckets in `CLOSE_DEF_DIST_ROUNDED` to compute FG% as a function of defender distance.
#
# After grouping, we plot the relation and... wait, why does defender distance not seem to matter!?
#
# _Question_
# + What might explain this seeming lack of relationship?  Does shot type matter?  Anything else?

# %%
result = t.select('CLOSE_DEF_DIST_ROUNDED', 'SHOT_RESULT_BIN').\
    group('CLOSE_DEF_DIST_ROUNDED', collect=np.mean)

result = result.relabel('SHOT_RESULT_BIN mean', 'SHOT_PCT')
result.where('CLOSE_DEF_DIST_ROUNDED', ds.are.below_or_equal_to(14)).\
    plot(column_for_xticks='CLOSE_DEF_DIST_ROUNDED', select='SHOT_PCT')

plt.gca().set_ylim(0, .7);

# %% [markdown]
# Okay, now we separate by shot type.  Clearly defender distance is a big deal for 3pt shots.  But it still doesn't seem that important for 2pt shots.
#
# _Question_
# + Should 2pt shooting % be immune defender distance?  Why or why not?  Is there something else missing?

# %%
result = t.select('PTS_TYPE', 'CLOSE_DEF_DIST_ROUNDED', 'SHOT_RESULT_BIN').\
    group(['PTS_TYPE', 'CLOSE_DEF_DIST_ROUNDED'], collect=np.mean)

result = result.relabel('SHOT_RESULT_BIN mean', 'SHOT_PCT')

result = result.pivot('PTS_TYPE', 'CLOSE_DEF_DIST_ROUNDED', values='SHOT_PCT', collect=np.mean)
result.where('CLOSE_DEF_DIST_ROUNDED', ds.are.below_or_equal_to(14)).\
    plot(column_for_xticks='CLOSE_DEF_DIST_ROUNDED', select=['2', '3'])

# %% [markdown]
# ## Shot Distance
#
# We can quickly visualize the variability in shot distance with a pair of histogram plots.  The distance of the NBA 3pt line is not uniform but generally you see the overall pattern of shots.

# %%
t.select('PTS_TYPE', 'SHOT_DIST').\
    pivot('PTS_TYPE', 'SHOT_DIST').\
    bar('SHOT_DIST', select=['2', '3'])

# %% [markdown]
# We can group by shot type and shot distance (rounded to nearest half foot) to get a feel for how shooting percentage varies with shot distance.  Obviously close in shots are layups/dunks that are almost always converted.

# %%
result = t.select('PTS_TYPE', 'SHOT_DIST_ROUNDED', 'SHOT_RESULT_BIN').\
    group(['PTS_TYPE', 'SHOT_DIST_ROUNDED'], collect=np.mean)

result = result.relabel('SHOT_RESULT_BIN mean', 'SHOT_PCT')

result = result.pivot('PTS_TYPE', 'SHOT_DIST_ROUNDED', values='SHOT_PCT', collect=np.mean)

result['2'][result['SHOT_DIST_ROUNDED'] > 24] = np.nan
result['3'][(result['SHOT_DIST_ROUNDED'] < 21) | (result['SHOT_DIST_ROUNDED'] > 29)] = np.nan

result.plot(column_for_xticks='SHOT_DIST_ROUNDED', select=['2', '3'])
plt.gca().set_ylim(0, .7);

# %% [markdown]
# ## Shot Distance and Defender Distance
#
# Okay, we saw defender distance mattered for 3s and shot distance matters.  Let's combine the two.  We use the shot distance buckets in `SHOT_DIST_BUCKET` as well as the rounded defender distance to show how shooting percentage varies both in shot distance and defender distance.

# %%
result = t.select('SHOT_DIST_BUCKET', 'CLOSE_DEF_DIST_ROUNDED', 'SHOT_RESULT_BIN').\
    group(['SHOT_DIST_BUCKET', 'CLOSE_DEF_DIST_ROUNDED'], collect=np.mean)
result = result.relabel('SHOT_RESULT_BIN mean', 'SHOT_PCT')

result = result.pivot(
    'SHOT_DIST_BUCKET', 'CLOSE_DEF_DIST_ROUNDED', values='SHOT_PCT', collect=np.mean)
result.where('CLOSE_DEF_DIST_ROUNDED', ds.are.below_or_equal_to(14)).\
    plot(column_for_xticks='CLOSE_DEF_DIST_ROUNDED')
plt.gca().set_ylim(0, 1.03);

# %% [markdown]
# ### Hexbin Plot
#
# We can view the relationship between the in more continuous space with a hexbin plot.  A hexbin plot segments the space and all shots that lie within a hexagon will be grouped together.  Then within that hexagon, we will compute the shooting percentage.  We can see how regardless of shot distance, the defender distance near 0 drives down shooting percentage at that distance from the basket.
#
# _Question_
# + Why are there some spots that are extra dark or white that don't really fit with the general pattern?
# + What is going on with that spike on the left side?  What kind of shot has a high percentage, is near the basket, and has no defender nearby?

# %%
from shot_location_helper import hexbin_plot

hexbin_plot(
    t.where('SHOT_DIST', ds.are.below_or_equal_to(30)),
    'SHOT_DIST',
    'CLOSE_DEF_DIST',
    C='SHOT_RESULT_BIN',
    collect=np.mean,
    gridsize=20,
    figsize=(10, 6),
    cmap=plt.cm.viridis_r,
    mincnt=5,
    vmin=0.2,
    vmax=0.8
);

# %% [markdown]
# ## Expected Shot Value
#
# We can do the same hexbin plot but compute expected points.  This makes more sense due to the 3pt line and represents a shooting efficiency due to the variable value of shots.
#
# _Question_
# + What does this hexbin plot say about mid/long-distance 2s as well?  How bad is a closely guarded mid/long 2 point shot?

# %%
hexbin_esv_plot = hexbin_plot(
    t.where('SHOT_DIST', ds.are.below_or_equal_to(30)),
    'SHOT_DIST',
    'CLOSE_DEF_DIST',
    C='PTS_MADE',
    collect=np.mean,
    gridsize=20,
    cmap=plt.cm.viridis_r,
    figsize=(10, 6),
    mincnt=5,
    vmin=0.5,
    vmax=1.6
)

# %% [markdown]
# ## An Improved Shooting Metric
#
# Recall the Effective Field Goal Pct was given by
# $$
#     \text{eFG\%} = \frac{\mathit{FG} + .5 \cdot \mathit{3FG}}{\mathit{FGA}} = \frac{\text{Total Points (excluding FT)}}{2 \cdot \mathit{FGA}}
# $$
#
# Ignoring the division by 2, our ESV computation is akin to the EFG computation: expected points scored per attempt.
#
# Here's a metric we can build along what we've seen already in baseball: for each shot use the hexbin plot to compute the ESV.  Then compute the points above average for each shot as
# $$
#     \text{Points Above Average} = \text{Points Made} - \text{Expected Shot Value}
# $$
#
# This is actually akin to what was proposed in this [paper][1] at the SLOAN conference.
#
# [1]: http://www.sloansportsconference.com/wp-content/uploads/2014/02/2014-SSAC-Quantifying-Shot-Quality-in-the-NBA.pdf

# %%
from shot_location_helper import build_expected_shot_values_from_hexbin

# Use a helper function to get the bin (and therefore ESV) for each shot
esv = build_expected_shot_values_from_hexbin(
    t['SHOT_DIST'], t['CLOSE_DEF_DIST'], hexbin_esv_plot)
t['EXPECTED_SHOT_VALUE'] = esv

# %%
t.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>GAME_ID</th> <th>MATCHUP</th> <th>LOCATION</th> <th>W</th> <th>FINAL_MARGIN</th> <th>SHOT_NUMBER</th> <th>PERIOD</th> <th>GAME_CLOCK</th> <th>SHOT_CLOCK</th> <th>DRIBBLES</th> <th>TOUCH_TIME</th> <th>SHOT_DIST</th> <th>PTS_TYPE</th> <th>SHOT_RESULT</th> <th>CLOSEST_DEFENDER</th> <th>CLOSEST_DEFENDER_PLAYER_ID</th> <th>CLOSE_DEF_DIST</th> <th>FGM</th> <th>PTS</th> <th>playerName</th> <th>SHOT_RESULT_BIN</th> <th>PTS_MADE</th> <th>CLOSE_DEF_DIST_ROUNDED</th> <th>SHOT_DIST_ROUNDED</th> <th>SHOT_DIST_BUCKET</th> <th>DATE</th> <th>PLAYER_TEAM</th> <th>OPP_TEAM</th> <th>HOME_TEAM</th> <th>AWAY_TEAM</th> <th>EXPECTED_SHOT_VALUE</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>21401229</td> <td>GSW vs. DEN</td> <td>H       </td> <td>W   </td> <td>7           </td> <td>1          </td> <td>2     </td> <td>02:05     </td> <td>10.6      </td> <td>2       </td> <td>3.3       </td> <td>6.5      </td> <td>2       </td> <td>made       </td> <td>Nurkic, Jusuf   </td> <td>203994                    </td> <td>2.1           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>2                     </td> <td>6.5              </td> <td>3-10            </td> <td>2015-04-15</td> <td>GSW        </td> <td>DEN     </td> <td>GSW      </td> <td>DEN      </td> <td>0.838157           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>1          </td> <td>1     </td> <td>03:55     </td> <td>6.2       </td> <td>1       </td> <td>1.8       </td> <td>4        </td> <td>2       </td> <td>missed     </td> <td>Koufos, Kosta   </td> <td>201585                    </td> <td>1.9           </td> <td>0   </td> <td>0   </td> <td>Andrew Bogut</td> <td>0              </td> <td>0       </td> <td>2                     </td> <td>4                </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td> <td>1.16842            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>2          </td> <td>1     </td> <td>03:54     </td> <td>5.2       </td> <td>0       </td> <td>0         </td> <td>2.8      </td> <td>2       </td> <td>made       </td> <td>Koufos, Kosta   </td> <td>201585                    </td> <td>2.2           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>2                     </td> <td>3                </td> <td>0-3             </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td> <td>1.22774            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>3          </td> <td>3     </td> <td>10:02     </td> <td>16        </td> <td>0       </td> <td>1.5       </td> <td>8.4      </td> <td>2       </td> <td>made       </td> <td>Udrih, Beno     </td> <td>2757                      </td> <td>4.4           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>4                     </td> <td>8.5              </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td> <td>0.901269           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21401212</td> <td>GSW vs. MEM</td> <td>H       </td> <td>W   </td> <td>4           </td> <td>4          </td> <td>3     </td> <td>08:26     </td> <td>1.4       </td> <td>0       </td> <td>0         </td> <td>4.5      </td> <td>2       </td> <td>made       </td> <td>Randolph, Zach  </td> <td>2216                      </td> <td>4.4           </td> <td>1   </td> <td>2   </td> <td>Andrew Bogut</td> <td>1              </td> <td>2       </td> <td>4                     </td> <td>4.5              </td> <td>3-10            </td> <td>2015-04-13</td> <td>GSW        </td> <td>MEM     </td> <td>GSW      </td> <td>MEM      </td> <td>1.44709            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (203585 rows omitted)</p

# %%
not_nan = ~np.isnan(esv)
t.where(not_nan).hist('EXPECTED_SHOT_VALUE', bins=50)

# %%
t['PTS_ABOVE_AVG'] = t['PTS_MADE'] - t['EXPECTED_SHOT_VALUE']
t.where(not_nan).hist('PTS_ABOVE_AVG', bins=50)

# %% [markdown]
# ### Player Points Above Average per FGA
# We can compute PAA per FGA for each player.

# %%
result = t.where(not_nan).\
    select('playerName', 'PTS_ABOVE_AVG').\
    group('playerName', collect=np.mean)
result_ct = t.select('playerName').group('playerName')   

paa = result.join('playerName', result_ct)

paa.relabel('PTS_ABOVE_AVG mean', 'PAAperFGA').\
    relabel('count', 'FGA')
# Out:
# playerName      | PAAperFGA  | FGA
# A.J. Price      | -0.0143649 | 137
# Aaron Brooks    | 0.0399828  | 809
# Aaron Gordon    | -0.100559  | 206
# Adreian Payne   | -0.106711  | 220
# Al Horford      | 0.112368   | 958
# Al Jefferson    | 0.0592335  | 1007
# Al-Farouq Aminu | -0.187976  | 355
# Alan Anderson   | 0.0998225  | 431
# Alec Burks      | -0.0833761 | 300
# Alex Kirk       | -0.504609  | 4
# ... (480 rows omitted)

# %%
paa.where('FGA', ds.are.above(100)).\
    sort('PAAperFGA', descending=True).\
    show(20)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>playerName</th> <th>PAAperFGA</th> <th>FGA</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Kyle Korver     </td> <td>0.379402 </td> <td>598 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Luke Babbitt    </td> <td>0.249144 </td> <td>192 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kevin Durant    </td> <td>0.227779 </td> <td>467 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hedo Turkoglu   </td> <td>0.226086 </td> <td>188 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Stephen Curry   </td> <td>0.216537 </td> <td>1319</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Brandan Wright  </td> <td>0.213496 </td> <td>361 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>JJ Redick       </td> <td>0.200852 </td> <td>933 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Anthony Morrow  </td> <td>0.200743 </td> <td>614 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DeAndre Jordan  </td> <td>0.200714 </td> <td>523 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Hassan Whiteside</td> <td>0.19178  </td> <td>380 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chris Paul      </td> <td>0.168376 </td> <td>1166</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Klay Thompson   </td> <td>0.160086 </td> <td>1282</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Damjan Rudez    </td> <td>0.150198 </td> <td>263 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Ed Davis        </td> <td>0.150001 </td> <td>460 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Meyers Leonard  </td> <td>0.145764 </td> <td>245 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>James Johnson   </td> <td>0.130042 </td> <td>400 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Wesley Matthews </td> <td>0.126162 </td> <td>751 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alexis Ajinca   </td> <td>0.124452 </td> <td>327 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dirk Nowitzki   </td> <td>0.122962 </td> <td>1062</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jason Terry     </td> <td>0.119604 </td> <td>442 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (364 rows omitted)</p

# %%
paa.where('FGA', ds.are.above(100)).\
    sort('PAAperFGA', descending=True).\
    take[-20:].show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>playerName</th> <th>PAAperFGA</th> <th>FGA</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Ramon Sessions     </td> <td>-0.164233</td> <td>330 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Luc Mbah a Moute   </td> <td>-0.165442</td> <td>614 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Cleanthony Early   </td> <td>-0.165908</td> <td>213 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tyler Ennis        </td> <td>-0.166638</td> <td>144 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jimmer Fredette    </td> <td>-0.168394</td> <td>166 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Lou Amundson       </td> <td>-0.179884</td> <td>248 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Al-Farouq Aminu    </td> <td>-0.187976</td> <td>355 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omer Asik          </td> <td>-0.192123</td> <td>411 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Markel Brown       </td> <td>-0.194708</td> <td>208 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Archie Goodwin     </td> <td>-0.199593</td> <td>199 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jerami Grant       </td> <td>-0.200009</td> <td>347 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Phil Pressey       </td> <td>-0.224261</td> <td>174 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Elijah Millsap     </td> <td>-0.232168</td> <td>234 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Spencer Dinwiddie  </td> <td>-0.241765</td> <td>169 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Johnny O'Bryant    </td> <td>-0.243336</td> <td>115 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Maurice Harkless   </td> <td>-0.247291</td> <td>156 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kostas Papanikolaou</td> <td>-0.254381</td> <td>189 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Darius Morris      </td> <td>-0.265714</td> <td>105 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Gary Harris        </td> <td>-0.291562</td> <td>217 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Reggie Evans       </td> <td>-0.29534 </td> <td>136 </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Team Points Above Average per 85 FGA
# We can compute PAA per 85 FGA for each team.  85 FGA is about 1 game.

# %%
paa_team = t.where(not_nan).\
    select('PLAYER_TEAM', 'PTS_ABOVE_AVG').\
    group('PLAYER_TEAM', collect=np.mean).\
    relabel('PTS_ABOVE_AVG mean', 'PAAperFGA')
paa_team['PAAper85FGA'] = 85 * paa_team['PAAperFGA']
paa_team.sort('PAAper85FGA', descending=True).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLAYER_TEAM</th> <th>PAAperFGA</th> <th>PAAper85FGA</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>GSW        </td> <td>0.0767843  </td> <td>6.52667    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LAC        </td> <td>0.0756277  </td> <td>6.42836    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAS        </td> <td>0.0390337  </td> <td>3.31786    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ATL        </td> <td>0.0374833  </td> <td>3.18608    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>POR        </td> <td>0.0329869  </td> <td>2.80389    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>TOR        </td> <td>0.0311852  </td> <td>2.65074    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CLE        </td> <td>0.0289933  </td> <td>2.46443    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>BKN        </td> <td>0.0241992  </td> <td>2.05693    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DAL        </td> <td>0.0213988  </td> <td>1.8189     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>WAS        </td> <td>0.0177247  </td> <td>1.5066     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>IND        </td> <td>0.00868578 </td> <td>0.738291   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIA        </td> <td>0.00285372 </td> <td>0.242566   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIL        </td> <td>-0.00223122</td> <td>-0.189654  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>OKC        </td> <td>-0.00360543</td> <td>-0.306461  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PHX        </td> <td>-0.00459342</td> <td>-0.390441  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NOP        </td> <td>-0.00639042</td> <td>-0.543186  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LAL        </td> <td>-0.00746014</td> <td>-0.634111  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CHI        </td> <td>-0.00844791</td> <td>-0.718073  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>HOU        </td> <td>-0.0107396 </td> <td>-0.912864  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MEM        </td> <td>-0.0125785 </td> <td>-1.06917   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORL        </td> <td>-0.0141177 </td> <td>-1.20001   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NYK        </td> <td>-0.0158917 </td> <td>-1.35079   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>BOS        </td> <td>-0.0178325 </td> <td>-1.51576   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAC        </td> <td>-0.0208463 </td> <td>-1.77194   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UTA        </td> <td>-0.02458   </td> <td>-2.0893    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIN        </td> <td>-0.0278921 </td> <td>-2.37083   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CHA        </td> <td>-0.0350032 </td> <td>-2.97527   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DEN        </td> <td>-0.0387922 </td> <td>-3.29734   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DET        </td> <td>-0.0421873 </td> <td>-3.58592   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PHI        </td> <td>-0.0926897 </td> <td>-7.87863   </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Player ESV

# %%
result = t.where(not_nan).\
    select('playerName', 'EXPECTED_SHOT_VALUE').\
    group('playerName', collect=np.mean)
result_ct = t.select('playerName').group('playerName')   

esv_players = result.join('playerName', result_ct)

esv_players = esv_players.relabel('EXPECTED_SHOT_VALUE mean', 'ESVperFGA').\
    relabel('count', 'FGA')

# %%
esv_players.where('FGA', ds.are.above(100)).\
    sort('ESVperFGA', descending=True).\
    show(40)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>playerName</th> <th>ESVperFGA</th> <th>FGA</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Tyson Chandler     </td> <td>1.22568  </td> <td>434 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Omer Asik          </td> <td>1.22375  </td> <td>411 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DeAndre Jordan     </td> <td>1.22266  </td> <td>523 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Joey Dorsey        </td> <td>1.17954  </td> <td>143 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Andre Roberson     </td> <td>1.16277  </td> <td>200 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Chris Andersen     </td> <td>1.16205  </td> <td>198 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Rudy Gobert        </td> <td>1.15796  </td> <td>424 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tony Allen         </td> <td>1.15318  </td> <td>447 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Reggie Evans       </td> <td>1.14828  </td> <td>136 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dewayne Dedmon     </td> <td>1.14296  </td> <td>158 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Larry Sanders      </td> <td>1.13249  </td> <td>170 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Maurice Harkless   </td> <td>1.13041  </td> <td>156 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tyler Hansbrough   </td> <td>1.12882  </td> <td>163 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tarik Black        </td> <td>1.12846  </td> <td>262 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Mason Plumlee      </td> <td>1.12258  </td> <td>451 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Alonzo Gee         </td> <td>1.11672  </td> <td>185 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Miles Plumlee      </td> <td>1.11184  </td> <td>245 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tiago Splitter     </td> <td>1.11143  </td> <td>301 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Timofey Mozgov     </td> <td>1.11129  </td> <td>564 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Al-Farouq Aminu    </td> <td>1.10629  </td> <td>355 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tristan Thompson   </td> <td>1.10557  </td> <td>480 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Andre Drummond     </td> <td>1.10259  </td> <td>949 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Bismack Biyombo    </td> <td>1.10245  </td> <td>185 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Andrew Bogut       </td> <td>1.09793  </td> <td>349 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>James Ennis        </td> <td>1.09736  </td> <td>246 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Kostas Papanikolaou</td> <td>1.09395  </td> <td>189 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Dwight Howard      </td> <td>1.091    </td> <td>406 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Aron Baynes        </td> <td>1.08865  </td> <td>324 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>James Johnson      </td> <td>1.08746  </td> <td>400 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Steven Adams       </td> <td>1.08673  </td> <td>392 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Thabo Sefolosha    </td> <td>1.08544  </td> <td>247 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Glen Davis         </td> <td>1.08275  </td> <td>255 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Amir Johnson       </td> <td>1.0798   </td> <td>515 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>John Henson        </td> <td>1.07906  </td> <td>336 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Matt Barnes        </td> <td>1.07852  </td> <td>618 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Tyreke Evans       </td> <td>1.07812  </td> <td>1160</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Ian Mahinmi        </td> <td>1.07613  </td> <td>211 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Thomas Robinson    </td> <td>1.07506  </td> <td>258 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Trevor Ariza       </td> <td>1.07461  </td> <td>896 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Ed Davis           </td> <td>1.0744   </td> <td>460 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (344 rows omitted)</p

# %%
esv_team = t.where(not_nan).\
    select('PLAYER_TEAM', 'EXPECTED_SHOT_VALUE').\
    group('PLAYER_TEAM', collect=np.mean).\
    relabel('EXPECTED_SHOT_VALUE mean', 'ESVperFGA')
esv_team['ESVper85FGA'] = 85 * esv_team['ESVperFGA']
esv_team.sort('ESVper85FGA', descending=True).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLAYER_TEAM</th> <th>ESVperFGA</th> <th>ESVper85FGA</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>HOU        </td> <td>1.03721  </td> <td>88.1631    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ATL        </td> <td>1.0205   </td> <td>86.7422    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PHI        </td> <td>1.01785  </td> <td>86.5171    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UTA        </td> <td>1.01464  </td> <td>86.2441    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CLE        </td> <td>1.01393  </td> <td>86.1843    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>PHX        </td> <td>1.01266  </td> <td>86.0763    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DET        </td> <td>1.0122   </td> <td>86.0368    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NOP        </td> <td>1.01173  </td> <td>85.9968    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DAL        </td> <td>1.01007  </td> <td>85.8563    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>GSW        </td> <td>1.00922  </td> <td>85.7833    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAC        </td> <td>1.00624  </td> <td>85.5306    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIL        </td> <td>1.00467  </td> <td>85.3972    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ORL        </td> <td>1.00459  </td> <td>85.3901    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DEN        </td> <td>1.00209  </td> <td>85.1781    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIA        </td> <td>1.00135  </td> <td>85.1149    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAS        </td> <td>1.00071  </td> <td>85.0601    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>BOS        </td> <td>0.998507 </td> <td>84.8731    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LAC        </td> <td>0.993837 </td> <td>84.4762    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MEM        </td> <td>0.993056 </td> <td>84.4098    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CHI        </td> <td>0.990567 </td> <td>84.1982    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>OKC        </td> <td>0.989967 </td> <td>84.1472    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>TOR        </td> <td>0.988576 </td> <td>84.029     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>POR        </td> <td>0.987477 </td> <td>83.9355    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>WAS        </td> <td>0.982721 </td> <td>83.5313    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>BKN        </td> <td>0.973525 </td> <td>82.7497    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MIN        </td> <td>0.966094 </td> <td>82.118     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>IND        </td> <td>0.963799 </td> <td>81.923     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>NYK        </td> <td>0.960201 </td> <td>81.617     </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>LAL        </td> <td>0.959245 </td> <td>81.5358    </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>CHA        </td> <td>0.950895 </td> <td>80.8261    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Does Defender Distance Relate to Shooter Quality?
#
# Presumably better shooters will be guarded more closely, right?  To study this, let's restrict to 3pt shots.

# %%
t.where('playerName', 'Stephen Curry').\
    where('PTS_TYPE', 3).\
    hist('CLOSE_DEF_DIST', bins=30)

# %% [markdown]
# We take all players with at least 50 shots, sort them by their 3FG% (from left to right), and construct boxplots showing defender distance.  If 3FG% indicates better shooters, and it should, then those players should be guarded tighter than poor shooters. We should see some kind of pattern in the plot that will reflect this hypothesis.
#
# _Question_
# + What pattern emerges from this plot?  Can you think of a plausible explanation?

# %%
from shot_location_helper import sorted_boxplot

num_3pt_shots = 50
by = 'playerName'
column = "CLOSE_DEF_DIST"

three_pt_shots = t.where('PTS_TYPE', 3)

result = three_pt_shots.select(by, 'SHOT_RESULT_BIN').\
    group(by, collect=np.mean)
result2 = three_pt_shots.select(by).group(by)
result = result.join(by, result2)
result.relabel('SHOT_RESULT_BIN mean', '3FG%').\
    relabel('count', 'FGA')
    
by_3pt_pct = result.where('FGA', ds.are.above(num_3pt_shots)).\
    sort('3FG%', descending=True) 
    
sorted_boxplot(
    three_pt_shots.to_df(),
    by,
    column,
    by_3pt_pct[by],
    figsize=(25, 10),
    fontsize=8
)
